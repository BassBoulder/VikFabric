# %%
import requests
import json
# Out:
# StatementMeta(, d7a98922-b5dc-4a7a-a3fc-9d84436b809e, 3, Finished, Available)

# %%
CLIENT_ID = '78163d2168824c64bdce6c8eefcb48c7'
CLIENT_SECRET = '02ace213014f4f1389aec38a557ff6f3'
# Out:
# StatementMeta(, d7a98922-b5dc-4a7a-a3fc-9d84436b809e, 4, Finished, Available)

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token'] #longevity of the token is 1 hour
# Out:
# StatementMeta(, d7a98922-b5dc-4a7a-a3fc-9d84436b809e, 5, Finished, Available)

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
# Out:
# StatementMeta(, d7a98922-b5dc-4a7a-a3fc-9d84436b809e, 6, Finished, Available)

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
b = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)
# Out:
# StatementMeta(, 40203167-ee9f-48e1-ae1b-2397fa5b1720, 7, Finished, Available)

# %%
test = test.json()
test
# Out:
# StatementMeta(, 40203167-ee9f-48e1-ae1b-2397fa5b1720, 8, Finished, Available)
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %%
output_file_path = "/lakehouse/default/Files/test.json"

# Write the data to the JSON file
with open(output_file_path, "w") as json_file:
    json.dump(test, json_file)
# Out:
# StatementMeta(, 40203167-ee9f-48e1-ae1b-2397fa5b1720, 11, Finished, Available)

# %%
# get artist songs data, I like RAYE
BASE_URL = 'https://api.spotify.com/v1/'
artist_id = '5KKpBU5eC2tJDzf0wmlRp2'

# pull 00 artists songs
r = requests.get(BASE_URL + 'artists/' + artist_id + '/top-tracks', 
                 headers=headers, 
                 params={'market': 'ES'})
                
raye_nolimit = r.json()
# Out:
# StatementMeta(, d7a98922-b5dc-4a7a-a3fc-9d84436b809e, 8, Finished, Available)

# %%
# load to bronze layer
output_file_path = "/lakehouse/default/Files/bronze/raye_tracks_nolimit.json"

with open(output_file_path, "w") as json_file:
    json.dump(raye_nolimit, json_file)
# Out:
# StatementMeta(, d7a98922-b5dc-4a7a-a3fc-9d84436b809e, 9, Finished, Available)
